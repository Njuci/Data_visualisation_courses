# %% [markdown]
# **3D Plots**

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import plotly.express as px

# Create a random dataset
#np.random.seed(123)
df = pd.DataFrame({'x': np.random.randn(100),
                   'y': np.random.randn(100),
                   'z': np.random.randn(100)})
print(df)

# Create a 3D scatter plot using Plotly and Cufflinks
fig = px.scatter_3d(df, x='x', y='y', z='z')
fig.show()
# Out:
#            x         y         z
# 0   0.702963 -0.378897 -1.278109
# 1   1.543750 -1.344331 -0.782531
# 2   0.772835 -1.055741  1.515841
# 3  -1.302865  2.401036 -0.006901
# 4  -1.499639  2.053065  0.442977
# ..       ...       ...       ...
# 95 -0.726196 -0.322439 -1.065046
# 96  0.757314 -0.607304  0.086234
# 97 -0.714563  0.594756  0.974636
# 98  1.830994 -0.247175  1.349255
# 99  0.666810  1.984086  0.104356
#
# [100 rows x 3 columns]

# %%
import cufflinks as cf
import plotly.express as px

# Load the iris dataset from Plotly
data = px.data.iris()
# Create a 3D scatter plot using Plotly and Cufflinks
fig = px.scatter_3d(data, x='sepal_width', y='sepal_length', z='petal_length', color='species')
fig.show()

# %% [markdown]
# ### Spread Plot and Hist Plot

# %%
import plotly.express as px
df = px.data.tips()
print(df)
# Spread Plot
fig = px.scatter(df, x="total_bill", y="tip", color="sex")
fig.show()

# Histogram Plot
fig = px.histogram(df, x="total_bill", nbins=30 , color="sex")
fig.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Bubble Plot and Heatmap

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import cufflinks as cf
cf.go_offline()

# Create a sample dataframe
df = pd.DataFrame({
    'x': np.random.rand(50),
    'y': np.random.rand(50),
    'size': np.random.rand(50),
    'color': np.random.randint(1, 4, size=50)
})

# Bubble plot
fig = px.scatter(df, x='x', y='y', size='size', color='color')
fig.show()

# Heatmap
heatmap_data = df.pivot_table(values='size', index='x', columns='y')
fig = px.imshow(heatmap_data, color_continuous_scale='twilight')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="11ba2df2-e140-4496-bcae-df46b9826c37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11ba2df2-e140-4496-bcae-df46b9826c37")) {                    Plotly.newPlot(                        "11ba2df2-e140-4496-bcae-df46b9826c37",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,2,2,2,1,2,2,1,1,3,1,2,1,2,3,3,1,2,1,1,3,1,2,1,2,1,3,3,1,1,1,3,1,1,3,2,2,3,2,1,1,2,1,1,3,1,2,1,1,3],"coloraxis":"coloraxis","size":[0.050875186246959414,0.8655504984864335,0.17803571096618986,0.9930014359117348,0.2188819022619617,0.14016475018132213,0.7596129409664008,0.480736192416392,0.7572819055980264,0.9580059652594726,0.22794695710842494,0.24492138444466027,0.06254033972178918,0.6159613032583723,0.7768738149448474,0.5598821362428626,0.8576409315900966,0.43288309870180763,0.5767968128345009,0.24099450955656931,0.07753297285435334,0.8571130372498944,0.11645071872798218,0.7248554387069264,0.284530143652894,0.11647162884928486,0.9346777374131934,0.017029938979605475,0.030681639576954134,0.47852439218897935,0.476569618427671,0.323334626146647,0.8774945972229988,0.7857079146570547,0.6342613236935366,0.5166108970538187,0.41917584212993386,0.7991280674306904,0.8347945529384256,0.5863752190551969,0.1861611860313347,0.24674882411020238,0.7512877369142608,0.5463361498975882,0.8358154994068425,0.6412691342453585,0.4108066320640462,0.32379847117542404,0.48912925927845385,0.11631430332958848],"sizemode":"area","sizeref":0.002482503589779337,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.7851007475810362,0.498300713301971,0.7480083109539767,0.2381842951932559,0.385445267023128,0.11728147836256797,0.9808737989265067,0.7725636171797721,0.21361706401353397,0.12885033192401518,0.16796749200818917,0.26737984999320175,0.8585122909742429,0.7894743163143335,0.7349405062204434,0.2201171390911003,0.0600658068958676,0.014190378864060826,0.1872246636421454,0.3847543474908929,0.5044271919005071,0.8598577056