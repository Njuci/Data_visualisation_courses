# %% [markdown]
# **3D Plots**

# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import plotly.express as px

# Create a random dataset
#np.random.seed(123)
df = pd.DataFrame({'x': np.random.randn(100),
                   'y': np.random.randn(100),
                   'z': np.random.randn(100)})

# Create a 3D scatter plot using Plotly and Cufflinks
fig = px.scatter_3d(df, x='x', y='y', z='z')
fig.show()

# %%
import cufflinks as cf
import plotly.express as px

# Load the iris dataset from Plotly
data = px.data.iris()
# Create a 3D scatter plot using Plotly and Cufflinks
fig = px.scatter_3d(data, x='sepal_width', y='sepal_length', z='petal_length', color='species')
fig.show()

# %% [markdown]
# ### Spread Plot and Hist Plot

# %%
import plotly.express as px
df = px.data.tips()
print(df)
# Spread Plot
fig = px.scatter(df, x="total_bill", y="tip", color="sex")
fig.show()

# Histogram Plot
fig = px.histogram(df, x="total_bill", nbins=30 , color="sex")
fig.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Bubble Plot and Heatmap

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import cufflinks as cf
cf.go_offline()

# Create a sample dataframe
df = pd.DataFrame({
    'x': np.random.rand(50),
    'y': np.random.rand(50),
    'size': np.random.rand(50),
    'color': np.random.randint(1, 4, size=50)
})

# Bubble plot
fig = px.scatter(df, x='x', y='y', size='size', color='color')
fig.show()

# Heatmap
heatmap_data = df.pivot_table(values='size', index='x', columns='y')
fig = px.imshow(heatmap_data, color_continuous_scale='twilight')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b00c6719-fc5f-4422-9f2d-8d6c5f9b7b63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b00c6719-fc5f-4422-9f2d-8d6c5f9b7b63")) {                    Plotly.newPlot(                        "b00c6719-fc5f-4422-9f2d-8d6c5f9b7b63",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2,2,2,1,2,3,3,3,1,1,1,2,1,2,3,3,3,3,1,1,3,2,2,1,3,2,1,2,3,2,1,1,3,1,2,1,3,1,1,2,3,2,3,3,3,3,2,1,2,1],"coloraxis":"coloraxis","size":[0.14455399751254427,0.9578301939397992,0.3906679411161249,0.34409641051728823,0.9858677439364676,0.8272173069200404,0.8000645895185325,0.5224775232784528,0.28035190152369116,0.7109037484582478,0.4229966709310279,0.9763795134929875,0.006399197523879296,0.005920558315777313,0.884767418336314,0.7865814737113398,0.12260032260663012,0.28309693011954806,0.16995785460337842,0.46671988307151113,0.7536260370263852,0.707102807970776,0.30509025566140013,0.939409913153857,0.9401868546421595,0.42309570926146,0.5134332310589159,0.6421024463413346,0.6165890695680589,0.35095648730349815,0.39124922771354287,0.5046369313292007,0.22276309461751154,0.5685731500891011,0.4194874128649727,0.37334950612865525,0.3478636137694707,0.18415835588644702,0.7714053064508345,0.06658610344211457,0.31891013494673426,0.274058610303602,0.9150855487294273,0.6494843665815799,0.03471941459449901,0.23252235304833657,0.2760675817538859,0.5949128929566964,0.8674506100493102,0.055726868339442404],"sizemode":"area","sizeref":0.002464669359841169,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.48660262362414786,0.5208210820989024,0.5089053869220557,0.2996865221185119,0.40454384823275,0.9288954222563317,0.5358173237535677,0.9521886642061139,0.5783205086874791,0.32527405156704725,0.14624534857721572,0.45838429259356117,0.15320451031432658,0.5963166767000331,0.7793470474015274,0.1568493628494888,0.7705590042049602,0.7778021521611159,0.10968551359641288,0.019803357538820454,0.15910314782227952,0.5236988712086325,0.03335099049356294,0.6900731062775662,0.001960183596913634,0.2704230112117919,0.20098579288944718,0.9631651013264093,0.6145130950714429,0.48503344440079155,0.7726226440027127,0.8703361071394287,0.500315599000451,0.04901596690444465,0.8241412314427287,0.7708283488995173